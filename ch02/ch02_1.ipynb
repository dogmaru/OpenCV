# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/ColabIP/Images/puppy.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

# %%
cv2.split(RGB_img)
# Out:
# (array([[ 69,  66,  65, ..., 121, 117, 116],
#         [ 45,  40,  39, ..., 126, 121, 119],
#         [ 40,  35,  32, ..., 125, 117, 115],
#         ...,
#         [ 44,  46,  49, ..., 144, 129, 120],
#         [ 47,  48,  50, ..., 145, 130, 121],
#         [ 49,  49,  50, ..., 145, 131, 121]], dtype=uint8),
#  array([[ 88,  85,  84, ..., 131, 126, 125],
#         [ 62,  58,  57, ..., 136, 130, 128],
#         [ 54,  51,  48, ..., 137, 129, 127],
#         ...,
#         [ 72,  74,  77, ..., 143, 131, 123],
#         [ 75,  76,  78, ..., 144, 132, 124],
#         [ 77,  77,  78, ..., 144, 132, 124]], dtype=uint8),
#  array([[43, 40, 39, ..., 81, 81, 80],
#         [20, 16, 15, ..., 86, 85, 83],
#         [18, 14, 11, ..., 87, 83, 81],
#         ...,
#         [34, 36, 39, ..., 95, 84, 78],
#         [35, 36, 38, ..., 96, 85, 79],
#         [37, 37, 38, ..., 96, 88, 79]], dtype=uint8))
