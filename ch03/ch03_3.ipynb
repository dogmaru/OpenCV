# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#img = cv2.imread('/content/gdrive/My Drive/ColabIP/Images/abcdef.bmp')
img = cv2.imread('/content/gdrive/My Drive/ColabIP/Images/lena256.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gImg.shape)
cv2_imshow(gImg)
# Out:
# (256, 256)
# <PIL.Image.Image image mode=L size=256x256>

# %%
#img = cv2.imread('/content/gdrive/My Drive/ColabIP/Images/a.bmp')
img = cv2.imread('/content/gdrive/My Drive/ColabIP/Images/circle.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg2 = cv2.cvtColor(RGB_img, cv2.COLOR_BGR2GRAY)
print(gImg2.shape)
cv2_imshow(gImg2)
# Out:
# (286, 322)
# <PIL.Image.Image image mode=L size=322x286>

# %%
gBit = np.zeros((gImg.shape[0], gImg.shape[1]), dtype=np.ubyte)

# %%
for h in range(gImg.shape[0]):
  for w in range(gImg.shape[1]):
    bitVal = gImg[h,w] | gImg2[h,w]
    #bitVal = gImg[h,w] & gImg2[h,w]
    #bitVal = gImg[h,w] ^ gImg2[h,w]
    gBit[h, w] = bitVal

cv2_imshow(gBit)
# Out:
# <PIL.Image.Image image mode=L size=256x256>
